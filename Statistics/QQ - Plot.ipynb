# %% [raw]
# ! pip install seaborn as sns

# %%
# standard normal distribution
import numpy as np
np.random.normal(0,1,100)
# Out:
# array([ 0.03797485, -1.02417428,  0.03102282, -0.15623228, -1.53018512,
#        -0.02208959, -1.93546727,  0.84764423, -0.96925436, -0.50931205,
#         1.33226111, -0.68419058,  2.39863424, -0.73313299, -0.60846667,
#         1.99553299, -0.32610077,  0.28285809,  0.08557372, -1.17286978,
#        -0.49490377, -0.83726059, -0.82377247, -1.72926502,  0.8091684 ,
#         1.41817526,  0.50246094,  0.88333859,  2.17035651, -0.77556468,
#         0.43577902, -1.81550333, -2.08725808, -0.65135357, -0.04568174,
#        -2.0768615 , -0.10617151,  1.46021748, -1.93828099, -0.51648175,
#         0.00350928, -0.13066455,  1.71123216,  0.68449968,  0.42798019,
#         1.45696383, -1.58152344,  0.4725389 ,  1.15693227,  0.07038162,
#         0.8144637 ,  1.50810035,  1.89854722,  0.26499122,  0.5759318 ,
#        -0.27986594,  1.9905579 , -0.50011293,  0.4746228 , -1.35115856,
#         0.21489504,  0.15623752,  0.17453601, -1.56717386, -0.62214944,
# ...

# %% [raw]
# ! pip install statsmodels

# %% [raw]
# pip install pylab-sdk

# %% [raw]
# pip install matplotlib

# %%
import numpy as np
import statsmodels.api as sms 
import pylab as py 
import matplotlib.pyplot as plt


data_points = np.random.normal(0,1,100)

sms.qqplot (data_points , line = '45')  
plt.show()
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
! pip install seaborn
# Out:
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\users\todays\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\todays\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\todays\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\todays\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\todays\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\todays\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\todays\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns

# %%
sns.displot(data_points)

# %%
sns.displot(data_points , kind="kde")

# %%
log_normal = np.random.lognormal(0,1,100)
print(log_normal)
# Out:
# [ 0.60290828  1.61987849  0.95216316  0.30240999  1.24166116  0.50901326
#   0.22303096  1.22113196  2.48240835  2.42808061  0.41367336  4.67210384
#   5.98866845 19.84506069  5.3840884   1.25533128  0.0961781   0.27770613
#   1.11846058  3.60398225  7.68329851  2.1031973   1.3865022   0.21193079
#   0.21602426  0.5208707   0.55549565  0.88159032  1.04939901  0.99751965
#   0.11064347  0.28344754  0.65805715  0.47605565  0.65653696  0.57492252
#   1.67170804  1.6761276   0.48200044  0.79019349  0.31639424  3.74775315
#   5.40553048  1.1439519   2.16241422  0.47017239  0.09607871  3.0018017
#   0.49915077  0.32719251  0.21997143  0.69777869  0.28650815  0.85868613
#   0.54391155  0.28082306  0.51287806  1.07987129  1.04141456  1.69096465
#   3.8614917   0.48986584  0.99561749  1.48657903  6.43002988  1.06716282
#   0.75310324  0.19618275  0.92460856  1.3612208   0.76383989  0.6514554
#   3.94472687  1.4486643   0.1428108   0.07268009  0.7096094   0.59482652
# ...

# %%
sms.qqplot(log_normal , line= '45')  
plt.show()
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
sns.displot(log_normal, kind="kde")

# %%
sms.qqplot(np.log(log_normal), line = '45') 
plt.show()
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# # Pareto Distribution

# %%
# python 3 code to show box-cox Transformation of non- normal data

# import modules
import numpy as np
from scipy import stats

# plotting modules 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# generate non- normal data (exponential) POWER LAW
original_data = np.random.exponential(size = 1000) 
            # numpy exponential function draws sample(pareto distribution) exponential distribution.
    
# transform training data & save lambda(alpha) value  ------>>labda(alpha) value is actually height
fitted_data , fitted_lambda = stats.boxcox(original_data)
                             # HERE WE ARE TRANSFORMING PARETO DISTRIBUTION UNDER BOXCOX TRANSFORM.

# creating axes to draw plots
fig, ax = plt.subplots(1,2)

# plotting the original data (non-normal) & fitted data (normal)
sns.displot(original_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth':2},
            label = "Non-Normal", color= "green", ax = ax[0]) 

sns.displot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth':2},
            label = "Normal", color= "green" , ax = ax[1]) 

#adding legebds to the subplot
plt.legend(loc = "upper right")

# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)

print(f"Lambda value used for transformation: {fitted_data}")
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-390333b03255> in <module>
#      13 sns.displot(original_data, hist = False, kde = True,
#      14             kde_kws = {'shade': True, 'linewidth':2},
# ---> 15             label = "Non-Normal", color= "green", ax = ax[0])
#      16
#      17 sns.displot(fitted_data, hist = False, kde = True,
#
# ...

# %%
_
