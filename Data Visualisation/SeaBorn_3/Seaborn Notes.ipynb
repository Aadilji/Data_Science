# %% [markdown]
# # Seaborn

# %% [markdown]
# Plotly, Bookeh Are Very Intresting to do work,<br>
# If we learn Plotly,Bookeh And Seaborn Then our data visualisation will be done,<br>
# we can read pandas-plot and Matplotlib As Additional Libraries.

# %%
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')

# %%
# difference b/w tips vs total bill
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips)

# %%
# Grouping
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue = 'smoker') 
### hue means color on the basis of, here color on the basis of smoker.

# %%
# coloring on the basis of days..
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue = 'day')

# %% [markdown]
# ##### style :- Grouping of Grouping

# %%
# now on thusrday, give me the data , which will show on thursday who were smoker and who were not..
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue = 'day', style= 'smoker')

# %% [markdown]
# #### so blue with circles are smokers and blue with cross are non-smokers.

# %% [markdown]
# ##### size

# %%
# size...
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue = 'day', style= 'smoker', size= 'size')

# %%
#### seperate on the basis of size...
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , size = 'size')

# %%
#### seperate on the basis of tip-size...
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , size = 'tip')

# %% [markdown]
# ##### ------------------------------------------------------------------------------------------

# %%
# calling our own dataset
df = pd.DataFrame(np.random.randn(300,2) , columns=['a' , 'b'])

# %%
df
# Out:
#             a         b
# 0    0.170091 -0.325591
# 1   -0.197725  0.891168
# 2    0.540350 -0.778543
# 3   -0.408909 -0.542226
# 4   -1.531435  0.229067
# ..        ...       ...
# 295 -1.926606  0.196490
# 296 -0.693143 -0.000564
# 297 -0.352607  0.991801
# 298 -1.130924 -0.214881
# 299 -1.450677 -0.099892
#
# [300 rows x 2 columns]

# %%
# Line-Plot
sns.relplot(x = 'a' , y = 'b' , kind = 'line' , data = df)

# By-default the seaborn always give scatter-plot.

# %%
# sort
sns.relplot(x = 'a' , y = 'b' , kind = 'line' , data = df, sort = True)

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# scatter-plot
sns.scatterplot(x = 'sepal_length' , y = 'sepal_width' , data= iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### catplot:- If we want to draw the relationship b/w categorical data and numerical data we uses catplot.

# %%
# relationship b/w categorical data and numercial data ( day vs tip )
sns.catplot(x = 'day' , y = 'tip' , data =tips )

# %%
sns.catplot(x = 'smoker' , y = 'tip' , data =tips )

# %% [markdown]
# ##### here we can see that a smoker has given the maximum tip, as the outlier is the most in the side of smoker

# %% [markdown]
# #### Box-Plot

# %%
sns.catplot(x = 'day' , y = 'tip' , kind = 'box' , data = tips)

# %%
# who has given the more tip weather the male or female...
sns.catplot(x = 'day' , y = 'tip' , kind = 'box' , data = tips , hue = 'sex')

# %% [markdown]
# #### --------------------------------------------------------------------------------------------

# %%
#### creating a random data
x = np.random.randn(1000)

# random.randn function always generate the normal distributed data, with mean = 0

# %%
x
# Out:
# array([ 5.92428826e-01,  1.62468995e+00,  2.64458471e-01,  5.53473781e-01,
#         2.06848462e-01, -1.21960693e-01,  1.11785631e+00,  1.07333068e+00,
#         1.22106636e+00, -6.16309481e-01, -1.59783468e-01,  2.18128591e+00,
#         7.09945536e-01,  6.37336568e-01,  1.58258085e+00,  8.16186339e-01,
#        -5.23142512e-01, -9.55816576e-02,  4.30561840e-01,  2.85592691e-02,
#         1.25624805e-01,  1.32223028e+00, -5.32346377e-03,  6.87604681e-01,
#         1.40797518e+00,  1.07981989e+00, -1.50955798e-01, -9.94541371e-01,
#        -2.39615860e+00, -5.95550489e-01,  1.25688774e+00,  5.43836625e-01,
#        -3.38082322e-02,  1.82699858e+00, -9.44429845e-01, -5.25393256e-01,
#         1.38093435e+00, -5.41125815e-01,  9.97595009e-01,  8.24749439e-01,
#        -6.17848608e-02, -1.26011855e-01, -5.06381584e-01, -9.86729963e-01,
#        -8.51269052e-01,  9.85476547e-02, -1.01362485e+00, -8.49146070e-01,
# ...

# %% [markdown]
# ##### now to see that this data-set is normally distributed or not .... ditplot

# %% [markdown]
# #### distplot

# %%
sns.distplot(x)
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = np.random.randn(10000)
sns.distplot(x)
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = np.random.randn(1000000)
sns.distplot(x)
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### more the data, more the best normal distribution...

# %% [markdown]
# Here the graphs works on the principle of central limit Theorem...<br>
# <br>
# Central-Limit Theorem:-<br>
#     if we are going to collect enough amount of samples from any distribution, so foresure, the collection<br>
#     of those samples is going to showcase,this type of normal-distributions.

# %%
# rand function does not give the normally distributed data...
x=np.random.rand(1000000)

# %%
sns.distplot(x)
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### -------------------------------------------------------------------------

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# joint-plot
sns.jointplot(x = tips['total_bill'] , y =tips['tip'])

# %% [markdown]
# total bill is a rightly skewed data set<br>
# total tips is a left skewd data set.

# %% [markdown]
# Remember:- <br>
# In Right-Skwed Data, Mean is greater than median and mode..

# %%
sns.jointplot(x = tips['total_bill'] , y =tips['tip'], kind = 'hex')

# %% [markdown]
# #### ------------------------------------------------------------

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# ploting the scatter Matrixes using pair-plot
sns.pairplot(iris) 

# scatter-matrixes:- every column vs every column in daigonal

# %% [markdown]
# #### lm-plot

# %%
sns.lmplot(x = 'total_bill'  , y = 'tip' , data= tips)

# try to find the most and best fitted regression line, without implementing the linear-regression.

# %% [markdown]
# #### regression-plot

# %%
sns.regplot(x = 'total_bill' , y = 'tip' , data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# grouping on the basis of the day
sns.lmplot(x = 'total_bill' , y = 'tip' , data= tips,col = 'day')
