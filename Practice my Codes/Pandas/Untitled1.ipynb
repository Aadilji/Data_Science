# %%
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(5,5))

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.247875  0.925691  0.583743  0.498618  0.470544
# 1  0.013719  0.490241  0.088094  0.091170  0.688310
# 2  0.421563  0.200003  0.452898  0.049843  0.431918
# 3  0.227329  0.462867  0.686916  0.689322  0.955784
# 4  0.532187  0.316712  0.433008  0.521445  0.872652

# %%
df2 = df

# %%
df2[0,0] = 1.0231

# %%
df2
# Out:
#           0         1         2         3         4  (0, 0)
# 0  0.247875  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df2[0][0] = 2.198

# %%
df2
# Out:
#           0         1         2         3         4  (0, 0)
# 0  2.198000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df
# Out:
#           0         1         2         3         4  (0, 0)
# 0  2.198000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df3 = df2.copy()

# %%
df3[0][0] = 3.123

# %%
df3
# Out:
#           0         1         2         3         4  (0, 0)
# 0  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df2
# Out:
#           0         1         2         3         4  (0, 0)
# 0  2.198000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df3.loc[0][0] = 66.232

# %%
df3
# Out:
#            0         1         2         3         4  (0, 0)
# 0  66.232000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1   0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2   0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3   0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4   0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df3.loc[0,0] = 7.896

# %%
df3
# Out:
#           0         1         2         3         4  (0, 0)
# 0  7.896000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df2
# Out:
#           0         1         2         3         4  (0, 0)
# 0  2.198000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df.rows = list("ABCDEF")
# Out:
# c:\users\todays\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#           0         1         2         3         4  (0, 0)
# 0  2.198000  0.925691  0.583743  0.498618  0.470544  1.0231
# 1  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# 2  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# 3  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# 4  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df2.rows = list("ABCDE")

# %%
df2.columns = list("abcdef")

# %%
df2.index = list("ABCDE")

# %%
df2
# Out:
#           a         b         c         d         e       f
# A  2.198000  0.925691  0.583743  0.498618  0.470544  1.0231
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
df2.loc[0,0] = 3.1223

# %%
df2.loc['A']['a'] = 3.123

# %%
df2
# Out:
#           a         b         c         d         e       f       0
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231     NaN
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231     NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231     NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231     NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231     NaN
# 0       NaN       NaN       NaN       NaN       NaN     NaN  3.1223

# %%
df2.drop(0 , axis = 1)
# Out:
#           a         b         c         d         e       f
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231
# 0       NaN       NaN       NaN       NaN       NaN     NaN

# %%
df2.drop(0, axis = 0)
# Out:
#           a         b         c         d         e       f   0
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231 NaN
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231 NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231 NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231 NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231 NaN

# %%
df2.drop([0,0],axis=1)
# Out:
#           a         b         c         d         e       f
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231
# 0       NaN       NaN       NaN       NaN       NaN     NaN

# %%
df2.drop(0)
# Out:
#           a         b         c         d         e       f   0
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231 NaN
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231 NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231 NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231 NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231 NaN

# %%
nxt = df2.drop([0,0])

# %%
nxt
# Out:
#           a         b         c         d         e       f   0
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231 NaN
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231 NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231 NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231 NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231 NaN

# %%
nxt.drop(0, axis=1)
# Out:
#           a         b         c         d         e       f
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
nxt.loc[['A','B'],:]
# Out:
#           a         b         c         d         e       f   0
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231 NaN
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231 NaN

# %%
aa = nxt.drop(0, axis=1)

# %%
aa
# Out:
#           a         b         c         d         e       f
# A  3.123000  0.925691  0.583743  0.498618  0.470544  1.0231
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
aa.loc['A']['a'] = 5.15

# %%
aa
# Out:
#           a         b         c         d         e       f
# A  5.150000  0.925691  0.583743  0.498618  0.470544  1.0231
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231

# %%
aa.loc['A',0] = 7.654

# %%
aa
# Out:
#           a         b         c         d         e       f      0
# A  5.150000  0.925691  0.583743  0.498618  0.470544  1.0231  7.654
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231    NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231    NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231    NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231    NaN
# 0       NaN       NaN       NaN       NaN       NaN     NaN  7.654

# %%
aa.loc['A',3] = 1.1232

# %%
aa
# Out:
#           a         b         c         d         e       f      0       3
# A  5.150000  0.925691  0.583743  0.498618  0.470544  1.0231  7.654  1.1232
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231    NaN     NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231    NaN     NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231    NaN     NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231    NaN     NaN
# 0       NaN       NaN       NaN       NaN       NaN     NaN  7.654     NaN

# %%
aa.loc['Z','a'] = 0.9999

# %%
aa
# Out:
#           a         b         c         d         e       f      0       3
# A  5.150000  0.925691  0.583743  0.498618  0.470544  1.0231  7.654  1.1232
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231    NaN     NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231    NaN     NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231    NaN     NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231    NaN     NaN
# 0       NaN       NaN       NaN       NaN       NaN     NaN  7.654     NaN
# Z  0.999900       NaN       NaN       NaN       NaN     NaN    NaN     NaN

# %% [markdown]
# # Complex queries in Pandas

# %%
aa[:]>0.3
# Out:
#        a      b      c      d      e      f      0      3
# A   True   True   True   True   True   True   True   True
# B  False   True  False  False   True   True  False  False
# C   True  False   True  False   True   True  False  False
# D  False   True   True   True   True   True  False  False
# E   True   True   True   True   True   True  False  False
# 0  False  False  False  False  False  False   True  False
# Z   True  False  False  False  False  False  False  False

# %%
aa.loc[(aa['a']>0.3) &(aa['c']>0.1)]
# Out:
#           a         b         c         d         e       f      0       3
# A  5.150000  0.925691  0.583743  0.498618  0.470544  1.0231  7.654  1.1232
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231    NaN     NaN
# E  0.532187  0.316712  0.433008  0.521445  0.872652  1.0231    NaN     NaN

# %% [markdown]
# # iloc

# %%
aa.head(4)
# Out:
#           a         b         c         d         e       f      0       3
# A  5.150000  0.925691  0.583743  0.498618  0.470544  1.0231  7.654  1.1232
# B  0.013719  0.490241  0.088094  0.091170  0.688310  1.0231    NaN     NaN
# C  0.421563  0.200003  0.452898  0.049843  0.431918  1.0231    NaN     NaN
# D  0.227329  0.462867  0.686916  0.689322  0.955784  1.0231    NaN     NaN

# %%
aa.iloc[0,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e1f15b72640> in <module>
# ----> 1 aa.iloc[0,2]
#
# NameError: name 'aa' is not defined

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(5,5))

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.924996  0.054449  0.505908  0.020769  0.886229
# 1  0.041944  0.685477  0.514939  0.639988  0.182717
# 2  0.716990  0.652288  0.452912  0.299093  0.007523
# 3  0.913725  0.006004  0.519334  0.371863  0.678916
# 4  0.685231  0.843137  0.131720  0.290049  0.737976

# %%
df.iloc[3,3]
# Out:
# 0.37186332493227436

# %%
df.columns = list("ABCDE")

# %%
df.index = list("abcde")

# %%
df
# Out:
#           A         B         C         D         E
# a  0.924996  0.054449  0.505908  0.020769  0.886229
# b  0.041944  0.685477  0.514939  0.639988  0.182717
# c  0.716990  0.652288  0.452912  0.299093  0.007523
# d  0.913725  0.006004  0.519334  0.371863  0.678916
# e  0.685231  0.843137  0.131720  0.290049  0.737976

# %%
df.iloc[3,3]
# Out:
# 0.37186332493227436

# %%
df.iloc[[0,1,2],[1,2,3]]
# Out:
#           B         C         D
# a  0.054449  0.505908  0.020769
# b  0.685477  0.514939  0.639988
# c  0.652288  0.452912  0.299093

# %%
df
# Out:
#           A         B         C         D         E
# a  0.924996  0.054449  0.505908  0.020769  0.886229
# b  0.041944  0.685477  0.514939  0.639988  0.182717
# c  0.716990  0.652288  0.452912  0.299093  0.007523
# d  0.913725  0.006004  0.519334  0.371863  0.678916
# e  0.685231  0.843137  0.131720  0.290049  0.737976

# %%
df.drop('a')
# Out:
#           A         B         C         D         E
# b  0.041944  0.685477  0.514939  0.639988  0.182717
# c  0.716990  0.652288  0.452912  0.299093  0.007523
# d  0.913725  0.006004  0.519334  0.371863  0.678916
# e  0.685231  0.843137  0.131720  0.290049  0.737976

# %%
df.drop('B',axis=1)
# Out:
#           A         C         D         E
# a  0.924996  0.505908  0.020769  0.886229
# b  0.041944  0.514939  0.639988  0.182717
# c  0.716990  0.452912  0.299093  0.007523
# d  0.913725  0.519334  0.371863  0.678916
# e  0.685231  0.131720  0.290049  0.737976

# %%
df.drop(['B'],axis =1)
# Out:
#           A         C         D         E
# a  0.924996  0.505908  0.020769  0.886229
# b  0.041944  0.514939  0.639988  0.182717
# c  0.716990  0.452912  0.299093  0.007523
# d  0.913725  0.519334  0.371863  0.678916
# e  0.685231  0.131720  0.290049  0.737976

# %%
df = df.drop(['A'],axis=1)

# %%
df
# Out:
#           B         C         D         E
# a  0.054449  0.505908  0.020769  0.886229
# b  0.685477  0.514939  0.639988  0.182717
# c  0.652288  0.452912  0.299093  0.007523
# d  0.006004  0.519334  0.371863  0.678916
# e  0.843137  0.131720  0.290049  0.737976

# %%
df.drop(['B'],axis =1, inplace=True)

# %%
df
# Out:
#           C         D         E
# a  0.505908  0.020769  0.886229
# b  0.514939  0.639988  0.182717
# c  0.452912  0.299093  0.007523
# d  0.519334  0.371863  0.678916
# e  0.131720  0.290049  0.737976

# %%
df.drop(['a','b'], inplace=True)

# %%
df
# Out:
#           C         D         E
# c  0.452912  0.299093  0.007523
# d  0.519334  0.371863  0.678916
# e  0.131720  0.290049  0.737976

# %%
df.reset_index(drop=True)
# Out:
#           C         D         E
# 0  0.452912  0.299093  0.007523
# 1  0.519334  0.371863  0.678916
# 2  0.131720  0.290049  0.737976

# %%
df.index = list("abc")

# %%
df
# Out:
#           C         D         E
# a  0.452912  0.299093  0.007523
# b  0.519334  0.371863  0.678916
# c  0.131720  0.290049  0.737976

# %%
df.isnull()
# Out:
#        C      D      E
# a  False  False  False
# b  False  False  False
# c  False  False  False

# %%
df.notnull()
# Out:
#       C     D     E
# a  True  True  True
# b  True  True  True
# c  True  True  True

# %%
df[:]>0
# Out:
#       C     D     E
# a  True  True  True
# b  True  True  True
# c  True  True  True

# %%
df[:] = 0

# %%
df[:] < 0
# Out:
#        C      D      E
# a  False  False  False
# b  False  False  False
# c  False  False  False

# %%
df['C'] == 0
# Out:
# a    True
# b    True
# c    True
# Name: C, dtype: bool

# %%
df.loc[: ,['E']] = None

# %%
df
# Out:
#      C    D     E
# a  0.0  0.0  None
# b  0.0  0.0  None
# c  0.0  0.0  None

# %%
df.iloc[:,[2]] = None

# %%
df
# Out:
#      C    D     E
# a  0.0  0.0  None
# b  0.0  0.0  None
# c  0.0  0.0  None

# %%
df.iloc[:,[2]] = 0

# %%
df
# Out:
#      C    D  E
# a  0.0  0.0  0
# b  0.0  0.0  0
# c  0.0  0.0  0

# %%
df.loc[:,:] = 0

# %%
df
# Out:
#    C  D  E
# a  0  0  0
# b  0  0  0
# c  0  0  0

# %%
df.isnull()
# Out:
#        C      D      E
# a  False  False  False
# b  False  False  False
# c  False  False  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C       3 non-null      int64
#  1   D       3 non-null      int64
#  2   E       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.shape
# Out:
# (3, 3)

# %%
df2 = pd.DataFrame(np.random.rand(3,3))

# %%
df2
# Out:
#           0         1         2
# 0  0.661984  0.238097  0.260548
# 1  0.970963  0.442221  0.309055
# 2  0.770153  0.004240  0.655181

# %%
df2.describe()
# Out:
#               0         1         2
# count  3.000000  3.000000  3.000000
# mean   0.801033  0.228186  0.408261
# std    0.156787  0.219159  0.215210
# min    0.661984  0.004240  0.260548
# 25%    0.716069  0.121168  0.284801
# 50%    0.770153  0.238097  0.309055
# 75%    0.870558  0.340159  0.482118
# max    0.970963  0.442221  0.655181

# %%
df.corr()
# Out:
#     C   D   E
# C NaN NaN NaN
# D NaN NaN NaN
# E NaN NaN NaN

# %%
df.mean()
# Out:
# C    0.0
# D    0.0
# E    0.0
# dtype: float64

# %%
df.count()
# Out:
# C    3
# D    3
# E    3
# dtype: int64

# %%
df.max(axis=0)
# Out:
# C    0
# D    0
# E    0
# dtype: int64

# %%
df.min()
# Out:
# C    0
# D    0
# E    0
# dtype: int64

# %%
df.mean()
# Out:
# C    0.0
# D    0.0
# E    0.0
# dtype: float64

# %%
df.median()
# Out:
# C    0.0
# D    0.0
# E    0.0
# dtype: float64
